# %%
pip install pyEOF
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 1.0 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Unable to determine R home: [Errno 2] No such file or directory: 'R'
#       cffi mode is CFFI_MODE.ANY
#       Looking for R home with: R RHOME
#       Unable to determine R home: [Errno 2] No such file or directory: 'R'
#       R home found: None
#       Error: rpy2 in API mode cannot be built without R in the PATH or R_HOME defined. Correct this or force ABI mode-only by defining the environment variable RPY2_CFFI_MODE=ABI
#       [end of output]
#
# ...

# %%
from pyEOF import *
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from pyEOF import *
#       2 import xarray as xr
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pyEOF'

# %%
olr_data = xr.open_dataset("/work/Austin/olr_from1979.nc")
olr_data.sel(time=slice('1979-01-01', '2001-12-31'))
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8401, lon: 144, lat: 73)
# Coordinates:
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2001-12-31
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
# Data variables:
#     olr      (time, lat, lon) float32 ...
# Attributes: (12/13)
#     CDI:            Climate Data Interface version 2.0.6 (https://mpimet.mpg....
#     Conventions:    CF-1.2
#     source:         ftp.cpc.ncep.noaa.gov precip/noaa..
#     title:          Daily Mean Interpolated OLR
#     description:    Data is interpolated in time and space from NOAA twice-da...
#     platform:       Observation
#     ...             ...
#     references:     https://www.esrl.noaa.gov/psd/data/gridded/data.interp_OL...
#     NCO:            4.0.0
#     Citation:       Liebmann and Smith: June 2006: Description of a Complete ...
# ...

# %%
olr_anom = (xr.open_mfdataset("/work/Austin/anom.OLR.*.nc", combine = "by_coords", parallel=True))       
olr_anom
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8395, lev: 1, lat: 73, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2001-12-31
#   * lev      (lev) int32 1
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 82.5 85.0 87.5 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
# Data variables:
#     anom     (time, lev, lat, lon) float32 dask.array<chunksize=(365, 1, 73, 144), meta=np.ndarray>

# %%
sst_data = xr.open_dataset("/work/DATA/Reanalysis/ERA5/sst/sst_1979.nc")
sst_data
# Out:
# <xarray.Dataset>
# Dimensions:    (lon: 576, lat: 360, time: 365, bnds: 2)
# Coordinates:
#   * lon        (lon) float32 0.3125 0.9375 1.562 2.188 ... 358.4 359.1 359.7
#   * lat        (lat) float32 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * time       (time) datetime64[ns] 1979-01-01T09:00:00 ... 1979-12-31T09:00:00
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     sst        (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.8.2 (http://mpimet.mpg.de/...
#     Conventions:  CF-1.6
#     history:      Wed Aug 31 12:42:57 2022: cdo -b 32 mergetime day???.nc tem...
#     frequency:    day
#     CDO:          Climate Data Operators version 1.8.2 (http://mpimet.mpg.de/...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
olr_ano = np.array(olr_anom.anom)
print(olr_ano.shape)
olr_mean = np.zeros((144, 8395))
for j in range(8395) :
    for i in range(144) :
        olr_mean[i, j] = np.sum(olr_origin[j, 30:43, i])/13
        
pca.fit(olr_mean)
olr_eof = pca.transform(olr_mean)
print(olr_eof.shape)
# Out:
# (8395, 1, 73, 144)
# (144, 2)

# %%
plt.figure()

plt.plot(olr_eof)
plt.show()
